# %%
from pymongo import MongoClient
import pandas as pd
from database import get_last_data

# %%
df = pd.DataFrame(get_last_data())
df.head()
# Out:
#                         _id  \
# 0  6890cd826af208a8f68db301
# 1  6890cd826af208a8f68db300
# 2  6890cd826af208a8f68db2ff
# 3  6890cd826af208a8f68db2fe
# 4  6890cd826af208a8f68db2fd
#
#                                                title  \
# 0                    tailwind css v4 custom variants
# 1  `ERROR: [VRFC 10-2063] Module <my_task> not fo...
# 2  SQL update query where table contains NVARCHAR...
# 3  How to use the default value of a param when i...
# 4                RMarkdown - flextable paging in pdf
#
#                                                 link  \
# 0  https://stackoverflow.com/questions/79725062/t...
# 1  https://stackoverflow.com/questions/79725063/e...
# 2  https://stackoverflow.com/questions/79725064/s...
# 3  https://stackoverflow.com/questions/79725066/h...
# 4  https://stackoverflow.com/questions/79725069/r...
#
#                                              summary  \
# 0  I am trying to create a hambuger menu that upo...
# ...
